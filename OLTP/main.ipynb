# %% [markdown]
# # OLTP - Database
# The database, as shown in the OLTP.jpg diagram, is meant to represent activity related to an e-commerce site.
#
# In this file I will:
#
# 1- Create the database (create_db.py)
#
# 2- Populate it with synthetic data (populate.py)
#
# 3- Error inyect the synthetic data (error_inyect.py)
#
# The idea is to have dirty data to prove our ETL incremental pipeline is resilient.

# %%
import pandas as pd

import sqlite3
from datetime import date

INITIAL_DATE = date(2026, 2, 2)

# %%
conn = sqlite3.connect('ecommerce-OLTP.db')

# %%
# Creates db in sqlite.
import scripts.create_db as create_db

create_db.main()

# %%
# Populates our db.
import scripts.populate as populate

populate.populate_db_first_time(conn, num_users=100, num_products=20, join_date=INITIAL_DATE)

# %%
# Import error injection module
import scripts.generate_invalid as generate_invalid
from datetime import date

# %%
# Connect to SQLite database
conn = sqlite3.connect('ecommerce-OLTP.db')

# %% [markdown]
# ## Testing change functionality

# %% [markdown]
# ### Users

# %%
df_users = pd.read_sql_query('SELECT * FROM users', conn)
df_users
# Out:
#     user_id            name                         email   join_date
# 0         1   Jessica Baker            dweber@example.com  2026-02-02
# 1         2   Kelly Morales   chandleranthony@example.com  2026-02-02
# 2         3  Candice Duncan   fergusondarlene@example.net  2026-02-02
# 3         4   James Schultz          hjohnson@example.org  2026-02-02
# 4         5   Kristen Horne           brian24@example.com  2026-02-02
# ..      ...             ...                           ...         ...
# 95       96   Kayla Stevens  gwendolynanthony@example.com  2026-02-02
# 96       97      Sean Myers           doris75@example.com  2026-02-02
# 97       98   Roberta Black           danny29@example.net  2026-02-02
# 98       99   Tyler Roberts           isaac12@example.net  2026-02-02
# 99      100     Amy Gregory       joseherrera@example.org  2026-02-02
#
# [100 rows x 4 columns]

# %%
populate.change_existent_users(conn, 100)

# %%
df_users = pd.read_sql_query('SELECT * FROM users', conn)
df_users
# Out:
#     user_id            name                       email   join_date
# 0         1   Jessica Baker   carlawilliams@example.com  2026-02-02
# 1         2   Kelly Morales       wardkayla@example.net  2026-02-02
# 2         3  Candice Duncan  samanthacuevas@example.com  2026-02-02
# 3         4   James Schultz          kbrown@example.net  2026-02-02
# 4         5   Kristen Horne     donnaclarke@example.net  2026-02-02
# ..      ...             ...                         ...         ...
# 95       96   Kayla Stevens   delgadotaylor@example.net  2026-02-02
# 96       97      Sean Myers     frenchshaun@example.org  2026-02-02
# 97       98   Roberta Black      rogersjohn@example.net  2026-02-02
# 98       99   Tyler Roberts         jenny69@example.org  2026-02-02
# 99      100     Amy Gregory     sheilalopez@example.org  2026-02-02
#
# [100 rows x 4 columns]

# %% [markdown]
# ### Products

# %%
df_products = pd.read_sql_query('SELECT * FROM products', conn)
df_products
# Out:
#     product_id               name     category   price  stock
# 0            1        Night Reach  Accessories  397.53    169
# 1            2       Spring South       Beauty   37.92    136
# 2            3     There American  Accessories  161.92    101
# 3            4  Stand Opportunity     Clothing   17.59     16
# 4            5     Again American     Clothing  140.46    186
# 5            6     Range Increase     Footwear  487.48     95
# 6            7     Character From  Electronics  106.52     23
# 7            8           Son Home  Accessories  341.07    145
# 8            9       Suddenly Gas  Accessories  334.61     66
# 9           10      Suddenly Hold     Footwear   38.61     65
# 10          11            Wind If     Footwear  228.38    198
# 11          12      Bad Education  Electronics   34.02     67
# 12          13      Possible Food     Footwear    9.63    167
# 13          14          Bill Feel  Accessories  329.63     72
# 14          15           Will Bad     Clothing  103.46     42
# 15          16      Charge Sister     Footwear  166.16     75
# 16          17       Such Partner     Footwear  444.12     82
# 17          18         Huge Stock     Clothing   77.73    108
# 18          19         Effort Ten  Electronics  163.73    117
# 19          20  Partner Interview  Accessories  241.65     14

# %%
populate.change_existent_products(conn, 20, price_range=[20, 1000])

# %%
df_products = pd.read_sql_query('SELECT * FROM products', conn)
df_products
# Out:
#     product_id               name     category   price  stock
# 0            1        Night Reach  Accessories   75.75    169
# 1            2       Spring South       Beauty  506.91    136
# 2            3     There American  Accessories  114.93    101
# 3            4  Stand Opportunity     Clothing   97.22     16
# 4            5     Again American     Clothing  893.07    186
# 5            6     Range Increase     Footwear  683.57     95
# 6            7     Character From  Electronics  898.60     23
# 7            8           Son Home  Accessories  354.92    145
# 8            9       Suddenly Gas  Accessories  877.23     66
# 9           10      Suddenly Hold     Footwear  126.67     65
# 10          11            Wind If     Footwear  644.75    198
# 11          12      Bad Education  Electronics  110.15     67
# 12          13      Possible Food     Footwear  981.67    167
# 13          14          Bill Feel  Accessories  214.38     72
# 14          15           Will Bad     Clothing  552.31     42
# 15          16      Charge Sister     Footwear  907.86     75
# 16          17       Such Partner     Footwear   67.39     82
# 17          18         Huge Stock     Clothing  171.99    108
# 18          19         Effort Ten  Electronics  551.34    117
# 19          20  Partner Interview  Accessories   79.25     14

# %% [markdown]
# ## Generate transactions

# %%
df_transactions = pd.read_sql_query('SELECT * FROM transactions', conn)
df_transactions
# Out:
# Empty DataFrame
# Columns: [transaction_id, date, user_id, product_id, quantity, price, payment_type, status]
# Index: []

# %%
from datetime import date

populate.create_new_transactions(conn, 300, date(2026, 2, 2), 300, [0.7, 0.3])
# Out:
# 272

# %%
df_transactions = pd.read_sql_query('SELECT * FROM transactions', conn)
df_transactions
# Out:
#      transaction_id        date  user_id  product_id  quantity    price  \
# 0                 1  2026-02-02       46           1         3   227.25
# 1                 2  2026-02-02       91           2         1   506.91
# 2                 3  2026-02-02       53          15         1   552.31
# 3                 3  2026-02-02       53          20         5   396.25
# 4                 3  2026-02-02       53           8         5  1774.60
# ..              ...         ...      ...         ...       ...      ...
# 267             212  2026-02-02       98           1         3   227.25
# 268             213  2026-02-02        6          10         4   506.68
# 269             214  2026-02-02       14           1         1    75.75
# 270             215  2026-02-02       61          17         3   202.17
# 271             216  2026-02-02       27          16         2  1815.72
#
#       payment_type   status
# 0             visa  success
# 1       mastercard  success
# 2             visa   failed
# 3             visa   failed
# 4             visa   failed
# ..             ...      ...
# 267  wire transfer   failed
# 268     mastercard   failed
# 269           visa  success
# 270           visa  success
# 271     mastercard   failed
#
# [272 rows x 8 columns]

# %%
# Generate invalid records for testing ETL robustness
print("Current database state before error injection:")
cursor = conn.cursor()
cursor.execute("SELECT COUNT(*) FROM users")
user_count = cursor.fetchone()[0]
cursor.execute("SELECT COUNT(*) FROM products")
product_count = cursor.fetchone()[0]
cursor.execute("SELECT COUNT(*) FROM transactions")
transaction_count = cursor.fetchone()[0]

print(f"  Users: {user_count}")
print(f"  Products: {product_count}")
print(f"  Transactions: {transaction_count}")
print()
# Out:
# Current database state before error injection:
#   Users: 100
#   Products: 20
#   Transactions: 272

# %%
# Generate invalid records using our error injection script
# This creates 50 invalid records with various data quality issues
invalid_records = generate_invalid.generate_invalid_records(
    count=100, 
    today='2026-02-02'
)

invalid_records
# Out:
# {'users': [{'user_id': 116,
#    'name': 'User 37',
#    'email': 'user116@example.com',
#    'join_date': None},
#   {'user_id': 117,
#    'name': 'User 83',
#    'email': 'user@',
#    'join_date': '2025-01-15'},
#   {'user_id': 118,
#    'name': 'User 13',
#    'email': 'user @email.com',
#    'join_date': '2025-01-15'},
#   {'user_id': 119,
#    'name': 'User 73',
#    'email': 'user.example.com',
#    'join_date': '2025-01-15'},
#   {'user_id': 120,
#    'name': 'User 90',
#    'email': 'user120@example.com',
#    'join_date': None},
#   {'user_id': 121,
#    'name': 'User 9',
#    'email': 'user @email.com',
#    'join_date': '2025-01-15'},
#   {'user_id': 122,
#    'name': 'User 40',
#    'email': 'user.example.com',
#    'join_date': '2025-01-15'},
#   {'user_id': 123,
#    'name': 'User 42',
#    'email': 'user123@example.com',
#    'join_date': None},
#   {'user_id': 124,
#    'name': 'User 37',
#    'email': 'user@',
#    'join_date': '2025-01-15'},
#   {'user_id': 125,
#    'name': 'User 47',
#    'email': 'user125@example.com',
#    'join_date': None}],
#  'products': [{'product_id': 29,
#    'name': 'Luxury Item 95',
#    'category': 'Accessories',
#    'price': 19045.76,
#    'stock': 10},
#   {'product_id': 30,
#    'name': 'Product 31',
#    'category': 'Footwear',
#    'price': 43.57,
#    'stock': -29},
#   {'product_id': 31,
#    'name': 'Luxury Item 26',
#    'category': 'Accessories',
#    'price': 13532.3,
#    'stock': 9},
#   {'product_id': 32,
#    'name': 'Product 83',
#    'category': 'Accessories',
#    'price': 98.31,
#    'stock': -42},
#   {'product_id': 33,
#    'name': 'Luxury Item 70',
#    'category': 'Accessories',
#    'price': 38519.33,
#    'stock': 2},
#   {'product_id': 34,
#    'name': 'Luxury Item 54',
#    'category': 'Accessories',
#    'price': 38486.14,
#    'stock': 3},
#   {'product_id': 35,
#    'name': 'Product 83',
#    'category': 'Electronics',
#    'price': 93.03,
#    'stock': -35},
#   {'product_id': 36,
#    'name': 'Luxury Item 6',
#    'category': 'Accessories',
#    'price': 19340.97,
#    'stock': 4},
#   {'product_id': 37,
#    'name': 'Luxury Item 30',
#    'category': 'Accessories',
#    'price': 15166.88,
#    'stock': 10}],
#  'transactions': [{'transaction_id': 60,
#    'date': '2026-02-02',
#    'user_id': 14,
#    'product_id': 26,
#    'quantity': 4,
#    'price': 69.06,
#    'payment_type': 'visa',
#    'status': 'failed'},
#   {'transaction_id': 9297,
#    'date': '2026-02-02',
#    'user_id': 115,
#    'product_id': 27,
#    'quantity': 0,
#    'price': 28.86,
#    'payment_type': 'mastercard',
#    'status': 'failed'},
#   {'transaction_id': 3458,
#    'date': '2026-02-02',
#    'user_id': 1,
#    'product_id': 18,
#    'quantity': 3,
#    'price': 86.34,
#    'payment_type': 'cash',
#    'status': 'success'},
#   {'transaction_id': 2761,
#    'date': '2026-02-02',
#    'user_id': 124,
#    'product_id': 27,
#    'quantity': 1,
#    'price': 36.31,
#    'payment_type': 'other',
#    'status': 'failed'},
#   {'transaction_id': 6705,
#    'date': '2026-02-02',
#    'user_id': 100,
#    'product_id': 63,
#    'quantity': 1,
#    'price': 63.13,
#    'payment_type': 'wire transfer',
#    'status': 'success'},
#   {'transaction_id': 6132,
#    'date': '2026-02-02',
#    'user_id': 7,
#    'product_id': 2,
#    'quantity': 0,
#    'price': 92.34,
#    'payment_type': 'mastercard',
#    'status': 'failed'},
#   {'transaction_id': 7631,
#    'date': '2026-02-02',
#    'user_id': 61,
#    'product_id': 1,
#    'quantity': 2,
#    'price': 54.82,
#    'payment_type': 'check',
#    'status': 'success'},
#   {'transaction_id': 5290,
#    'date': '2026-02-02',
#    'user_id': 113,
#    'product_id': 15,
#    'quantity': 4,
#    'price': 24.99,
#    'payment_type': 'Bitcoin',
#    'status': 'success'},
#   {'transaction_id': 7675,
#    'date': '2026-02-02',
#    'user_id': 86,
#    'product_id': 11,
#    'quantity': 1,
#    'price': 67.8,
#    'payment_type': 'mastercard',
#    'status': 'refunded'},
#   {'transaction_id': 7627,
#    'date': '2026-02-02T00:00:00Z',
#    'user_id': 9,
#    'product_id': 3,
#    'quantity': 3,
#    'price': 28.71,
#    'payment_type': 'visa',
#    'status': 'failed'},
#   {'transaction_id': 5075,
#    'date': '2026-02-02',
#    'user_id': 43,
#    'product_id': 20,
#    'quantity': 4,
#    'price': 88.78,
#    'payment_type': 'other',
#    'status': 'success'},
#   {'transaction_id': 4201,
#    'date': '2026-02-02',
#    'user_id': 113,
#    'product_id': 23,
#    'quantity': 0,
#    'price': 12.01,
#    'payment_type': 'mastercard',
#    'status': 'failed'},
#   {'transaction_id': 6159,
#    'date': '2026-02-02',
#    'user_id': 67,
#    'product_id': 18,
#    'quantity': -1,
#    'price': 86.36,
#    'payment_type': 'mastercard',
#    'status': 'success'},
#   {'transaction_id': 2181,
#    'date': '2026-02-02',
#    'user_id': 97,
#    'product_id': 21,
#    'quantity': 0,
#    'price': 80.93,
#    'payment_type': 'other',
#    'status': 'failed'},
#   {'transaction_id': 4378,
#    'date': '2026-02-02',
#    'user_id': 117,
#    'product_id': 9,
#    'quantity': 1,
#    'price': 61.46,
#    'payment_type': 'other',
#    'status': 'failed'},
#   {'transaction_id': 3214,
#    'date': '2026-02-02',
#    'user_id': 18,
#    'product_id': 18,
#    'quantity': 3,
#    'price': 24.25,
#    'payment_type': 'bank_transfer',
#    'status': 'success'},
#   {'transaction_id': 8729,
#    'date': '2026-02-02',
#    'user_id': 31,
#    'product_id': 22,
#    'quantity': 0,
#    'price': 85.66,
#    'payment_type': 'visa',
#    'status': 'failed'},
#   {'transaction_id': 3059,
#    'date': '2026-02-02',
#    'user_id': 182,
#    'product_id': 18,
#    'quantity': 5,
#    'price': 77.52,
#    'payment_type': 'mastercard',
#    'status': 'failed'},
#   {'transaction_id': 9109,
#    'date': '2026-02-02',
#    'user_id': 177,
#    'product_id': 14,
#    'quantity': 5,
#    'price': 29.01,
#    'payment_type': 'wire transfer',
#    'status': 'failed'},
#   {'transaction_id': 8490,
#    'date': '2026-02-02',
#    'user_id': 114,
#    'product_id': 61,
#    'quantity': 5,
#    'price': 93.89,
#    'payment_type': 'mastercard',
#    'status': 'success'},
#   {'transaction_id': 8652,
#    'date': '2026-02-02',
#    'user_id': 86,
#    'product_id': 6,
#    'quantity': 1,
#    'price': 62.81,
#    'payment_type': 'bank_transfer',
#    'status': 'success'},
#   {'transaction_id': 5165,
#    'date': '2026-02-02',
#    'user_id': 14,
#    'product_id': 22,
#    'quantity': 0,
#    'price': 91.43,
#    'payment_type': 'other',
#    'status': 'failed'},
#   {'transaction_id': 44,
#    'date': '2026-02-02',
#    'user_id': 72,
#    'product_id': 21,
#    'quantity': 2,
#    'price': 83.32,
#    'payment_type': 'mastercard',
#    'status': 'success'},
#   {'transaction_id': 8948,
#    'date': '2026-02-02',
#    'user_id': 70,
#    'product_id': 16,
#    'quantity': -2,
#    'price': 37.03,
#    'payment_type': 'visa',
#    'status': 'success'},
#   {'transaction_id': 4396,
#    'date': '2026-02-02',
#    'user_id': 81,
#    'product_id': 17,
#    'quantity': 1,
#    'price': 89.95,
#    'payment_type': 'cash',
#    'status': 'success'},
#   {'transaction_id': 6252,
#    'date': '2026-02-02',
#    'user_id': 101,
#    'product_id': 28,
#    'quantity': 1,
#    'price': 20161.93,
#    'payment_type': 'wire transfer',
#    'status': 'success'},
#   {'transaction_id': 9796,
#    'date': '2026-02-02',
#    'user_id': 51,
#    'product_id': 26,
#    'quantity': 4,
#    'price': 11.03,
#    'payment_type': 'check',
#    'status': 'success'},
#   {'transaction_id': 8346,
#    'date': '2026-02-02',
#    'user_id': 94,
#    'product_id': 14,
#    'quantity': -1,
#    'price': 35.89,
#    'payment_type': 'other',
#    'status': 'success'},
#   {'transaction_id': 8438,
#    'date': '2026-02-02',
#    'user_id': 144,
#    'product_id': 1,
#    'quantity': 2,
#    'price': 20.42,
#    'payment_type': 'visa',
#    'status': 'success'},
#   {'transaction_id': 97,
#    'date': '2026-02-02',
#    'user_id': 43,
#    'product_id': 19,
#    'quantity': 4,
#    'price': 73.67,
#    'payment_type': 'wire transfer',
#    'status': 'success'},
#   {'transaction_id': 107,
#    'date': '2026-02-02',
#    'user_id': 113,
#    'product_id': 26,
#    'quantity': 5,
#    'price': 16.29,
#    'payment_type': 'other',
#    'status': 'success'}]}

# %%
# Insert the invalid records into the database
print("Inserting invalid records into OLTP database...")
inserted_count = generate_invalid.insert_invalid_records(invalid_records)
print(f"Successfully inserted {inserted_count} invalid records")
# Out:
# Inserting invalid records into OLTP database...
# Successfully inserted 50 invalid records

# %%
# Verify the invalid data was inserted by checking final counts
print("\nDatabase state after error injection:")
cursor.execute("SELECT COUNT(*) FROM users")
new_user_count = cursor.fetchone()[0]
cursor.execute("SELECT COUNT(*) FROM products")
new_product_count = cursor.fetchone()[0]
cursor.execute("SELECT COUNT(*) FROM transactions")
new_transaction_count = cursor.fetchone()[0]

print(f"  Users: {new_user_count} (+{new_user_count - user_count})")
print(f"  Products: {new_product_count} (+{new_product_count - product_count})")  
print(f"  Transactions: {new_transaction_count} (+{new_transaction_count - transaction_count})")
print(f"  Total new records: {(new_user_count - user_count) + (new_product_count - product_count) + (new_transaction_count - transaction_count)}")
# Out:
# Database state after error injection:
#   Users: 115 (+15)
#   Products: 28 (+8)
#   Transactions: 299 (+27)
#   Total new records: 50

# %% [markdown]
# ## Data Quality Issues Injected
#
# The following types of invalid data were injected to test ETL robustness:
#
# 1. **Orphan Transactions** - Transactions referencing non-existent users/products
# 2. **Invalid Quantities** - Zero or negative quantity transactions
# 3. **Price Violations** - Products with prices >= $10,000
# 4. **Price Mismatches** - Transaction prices not matching product prices
# 5. **Invalid Payment Types** - Unsupported payment methods (Bitcoin, PayPal, etc.)
# 6. **Invalid Status Values** - Transaction statuses outside success/failed
# 7. **Bad Date Formats** - Incorrectly formatted transaction dates
# 8. **Duplicate Transaction IDs** - Multiple transactions with same ID
# 9. **Invalid User Data** - Empty names, bad emails, NULL join dates
# 10. **Invalid Product Data** - Negative stock values
#
# These data quality issues will test the ETL pipeline's ability to:
# - Handle orphan records gracefully
# - Validate data constraints
# - Normalize inconsistent formats
# - Detect and handle duplicates
# - Apply business rules and data contracts

# %%
# Out:
# Sample Invalid Records Created:
#
# ==================================================
# Sample problematic transactions:
#    transaction_id        date  user_id  product_id  quantity    price  \
# 0               3  2026-02-02       53          15         1   552.31
# 1               3  2026-02-02       53          20         5   396.25
# 2               3  2026-02-02       53           8         5  1774.60
# 3               3  2026-02-02       53          12         2   220.30
# 4               5  2026-02-02       84          11         4  2579.00
# 5               5  2026-02-02       84          13         4  3926.68
# 6               5  2026-02-02       84          12         2   220.30
# 7               5  2026-02-02       84           8         2   709.84
# 8               9  2026-02-02       84          16         2  1815.72
# 9               9  2026-02-02       84           4         3   291.66
#
#     payment_type   status
# 0           visa   failed
# 1           visa   failed
# 2           visa   failed
# 3           visa   failed
# 4  wire transfer  success
# 5  wire transfer  success
# 6  wire transfer  success
# 7  wire transfer  success
# 8     mastercard  success
# 9     mastercard  success
#
# ==================================================

# %%
# Close the connection
conn.close()

# %%
df_transactions = pd.read_sql_query('SELECT * FROM transactions', conn)
df_transactions
# Out:
#      transaction_id        date  user_id  product_id  quantity    price  \
# 0                 1  2026-02-02       46           1         3   227.25
# 1                 2  2026-02-02       91           2         1   506.91
# 2                 3  2026-02-02       53          15         1   552.31
# 3                 3  2026-02-02       53          20         5   396.25
# 4                 3  2026-02-02       53           8         5  1774.60
# ..              ...         ...      ...         ...       ...      ...
# 294            5734  02-02-2026        9          13         5    16.70
# 295            8491  2026-02-02       66           9         2    75.47
# 296            3718  2026-02-02       59           1        -4    72.90
# 297            7990  2026-02-02       50           9        -2    22.84
# 298            7938  2026-02-02       96          17         5    56.83
#
#       payment_type   status
# 0             visa  success
# 1       mastercard  success
# 2             visa   failed
# 3             visa   failed
# 4             visa   failed
# ..             ...      ...
# 294          other   failed
# 295     mastercard  unknown
# 296  wire transfer  success
# 297           visa  success
# 298          other  success
#
# [299 rows x 8 columns]
